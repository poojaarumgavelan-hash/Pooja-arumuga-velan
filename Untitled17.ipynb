# %% [markdown]
# <a href="https://colab.research.google.com/github/poojaarumgavelan-hash/Pooja-arumuga-velan/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 100
b = 10
print(f"The Sum = {a + b}")
print(f"The Difference = {a - b}")
print(f"The Product = {a * b}")
print(f"The Quotient = {a / b:.1f}")
print(f"The Remainder = {a % b}")
print(f"The Exponent = {a ** 2:.0f}")
print(f"The Floor Division = {a // b}")
# Out:
# The Sum = 110
# The Difference = 90
# The Product = 1000
# The Quotient = 10.0
# The Remainder = 0
# The Exponent = 10000
# The Floor Division = 10
